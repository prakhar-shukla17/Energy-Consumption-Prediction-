# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
color_pal = sns.color_palette()

# %%
### Load the dataset
df=pd.read_csv('data\PJME_hourly.csv')
df.head()
df=df.set_index('Datetime')
df.index=pd.to_datetime(df.index)

# %%
df.plot(style='.', figsize=(15, 5), title='PJME Hourly Energy Consumption',color=color_pal[0])
plt.show()

# %%
# Plot the rolling mean of the energy consumption
df['PJME_MW'].rolling(window=24).mean().plot(figsize=(15, 6), color='red')
plt.title('24-Hour Rolling Mean of Energy Consumption')
plt.xlabel('Date')
plt.ylabel('Energy Consumption (MW)')
plt.grid(True)
plt.show()

# %%
#Monthly Average Consumption
monthly_avg = df['PJME_MW'].resample('M').mean()
plt.figure(figsize=(15,6))
monthly_avg.plot()
plt.title('Monthly Average Energy Consumption')
plt.xlabel('Month')
plt.ylabel('Average Energy (MW)')
plt.grid(True)
plt.show()

# %%
#Heatmap of missing values (if any)
print(df.isnull().sum())
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False)
plt.title('Heatmap of Missing Values')
plt.show()
# Out:
# PJME_MW    0
# dtype: int64

# %%
# Correlation Analysis
print("\nCorrelation Matrix:")
print(df.corr())

sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# Correlation Matrix:
#          PJME_MW
# PJME_MW      1.0
